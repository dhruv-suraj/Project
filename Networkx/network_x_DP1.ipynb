# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import networkx as nx

# %%
df1=pd.read_csv('Train_Inpatientdata.csv')
df1.head()
# Out:
#       BeneID   ClaimID ClaimStartDt  ClaimEndDt  Provider  \
# 0  BENE11001  CLM46614   2009-04-12  2009-04-18  PRV55912
# 1  BENE11001  CLM66048   2009-08-31  2009-09-02  PRV55907
# 2  BENE11001  CLM68358   2009-09-17  2009-09-20  PRV56046
# 3  BENE11011  CLM38412   2009-02-14  2009-02-22  PRV52405
# 4  BENE11014  CLM63689   2009-08-13  2009-08-30  PRV56614
#
#    InscClaimAmtReimbursed AttendingPhysician OperatingPhysician  \
# 0                   26000          PHY390922                NaN
# 1                    5000          PHY318495          PHY318495
# 2                    5000          PHY372395                NaN
# 3                    5000          PHY369659          PHY392961
# 4                   10000          PHY379376          PHY398258
#
#   OtherPhysician AdmissionDt  ... ClmDiagnosisCode_7  ClmDiagnosisCode_8  \
# 0            NaN  2009-04-12  ...               2724               19889
# 1            NaN  2009-08-31  ...                NaN                 NaN
# 2      PHY324689  2009-09-17  ...                NaN                 NaN
# 3      PHY349768  2009-02-14  ...              25062               40390
# 4            NaN  2009-08-13  ...               5119               29620
#
#   ClmDiagnosisCode_9 ClmDiagnosisCode_10 ClmProcedureCode_1  \
# 0               5849                 NaN                NaN
# 1                NaN                 NaN             7092.0
# 2                NaN                 NaN                NaN
# 3               4019                 NaN              331.0
# 4              20300                 NaN             3893.0
#
#   ClmProcedureCode_2 ClmProcedureCode_3 ClmProcedureCode_4 ClmProcedureCode_5  \
# 0                NaN                NaN                NaN                NaN
# 1                NaN                NaN                NaN                NaN
# 2                NaN                NaN                NaN                NaN
# 3                NaN                NaN                NaN                NaN
# 4                NaN                NaN                NaN                NaN
#
#   ClmProcedureCode_6
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN
#
# [5 rows x 30 columns]

# %%
df1['Provider']
# Out:
# 0        PRV55912
# 1        PRV55907
# 2        PRV56046
# 3        PRV52405
# 4        PRV56614
#            ...
# 40469    PRV53671
# 40470    PRV54981
# 40471    PRV56588
# 40472    PRV56575
# 40473    PRV54765
# Name: Provider, Length: 40474, dtype: object

# %%
df2=pd.read_csv('Train.csv')
df2.head()
# Out:
#    Provider PotentialFraud
# 0  PRV51001             No
# 1  PRV51003            Yes
# 2  PRV51004             No
# 3  PRV51005            Yes
# 4  PRV51007             No

# %%
df2['Provider'][0]
# Out:
# 'PRV51001'

# %%
df1['Provider'][0]
# Out:
# 'PRV55912'

# %%
df = pd.merge(df1, df2)
df
# Out:
#            BeneID   ClaimID ClaimStartDt  ClaimEndDt  Provider  \
# 0       BENE11001  CLM46614   2009-04-12  2009-04-18  PRV55912
# 1       BENE17521  CLM34721   2009-01-20  2009-02-01  PRV55912
# 2       BENE21718  CLM72336   2009-10-17  2009-11-04  PRV55912
# 3       BENE22934  CLM73394   2009-10-25  2009-10-29  PRV55912
# 4       BENE24402  CLM32911   2009-01-08  2009-01-12  PRV55912
# ...           ...       ...          ...         ...       ...
# 40469  BENE156181  CLM57017   2009-06-24  2009-07-01  PRV55706
# 40470  BENE156872  CLM67045   2009-09-06  2009-09-13  PRV51572
# 40471  BENE157414  CLM76036   2009-11-15  2009-11-23  PRV55688
# 40472  BENE158281  CLM35143   2009-01-23  2009-01-23  PRV56485
# 40473  BENE159166  CLM38985   2009-02-18  2009-02-25  PRV51812
#
#        InscClaimAmtReimbursed AttendingPhysician OperatingPhysician  \
# 0                       26000          PHY390922                NaN
# 1                       19000          PHY349293          PHY370861
# 2                       17000          PHY334706          PHY334706
# 3                       13000          PHY390614          PHY323689
# 4                        3000          PHY380413          PHY432598
# ...                       ...                ...                ...
# 40469                   12000          PHY319644          PHY319644
# 40470                    5000          PHY407588          PHY311768
# 40471                   14000          PHY409302                NaN
# 40472                   10000          PHY367360          PHY367360
# 40473                    6000          PHY430902          PHY430902
#
#       OtherPhysician AdmissionDt  ... ClmDiagnosisCode_8  ClmDiagnosisCode_9  \
# 0                NaN  2009-04-12  ...              19889                5849
# 1          PHY363291  2009-01-20  ...               2753               E9305
# 2                NaN  2009-10-17  ...              43812                4019
# 3          PHY363291  2009-10-25  ...                NaN                 NaN
# 4                NaN  2009-01-08  ...                NaN                 NaN
# ...              ...         ...  ...                ...                 ...
# 40469      PHY403799  2009-06-24  ...               1985                0414
# 40470      PHY311768  2009-09-06  ...              41401                2639
# 40471            NaN  2009-11-15  ...              V0481                2761
# 40472            NaN  2009-01-23  ...               2866                 NaN
# 40473            NaN  2009-02-18  ...              25000               32723
#
#       ClmDiagnosisCode_10 ClmProcedureCode_1 ClmProcedureCode_2  \
# 0                     NaN                NaN                NaN
# 1                     NaN             7769.0             5849.0
# 2                     NaN             9338.0                NaN
# 3                     NaN             8154.0                NaN
# 4                     NaN             8543.0                NaN
# ...                   ...                ...                ...
# 40469                 NaN             9955.0                NaN
# 40470                 NaN             3326.0                NaN
# 40471                 NaN                NaN                NaN
# 40472                 NaN             9390.0                NaN
# 40473                2724             3324.0                NaN
#
#       ClmProcedureCode_3 ClmProcedureCode_4 ClmProcedureCode_5  \
# 0                    NaN                NaN                NaN
# 1                    NaN                NaN                NaN
# 2                    NaN                NaN                NaN
# 3                    NaN                NaN                NaN
# 4                    NaN                NaN                NaN
# ...                  ...                ...                ...
# 40469                NaN                NaN                NaN
# 40470                NaN                NaN                NaN
# 40471                NaN                NaN                NaN
# 40472                NaN                NaN                NaN
# 40473                NaN                NaN                NaN
#
#       ClmProcedureCode_6 PotentialFraud
# 0                    NaN            Yes
# 1                    NaN            Yes
# 2                    NaN            Yes
# 3                    NaN            Yes
# 4                    NaN            Yes
# ...                  ...            ...
# 40469                NaN             No
# 40470                NaN             No
# 40471                NaN             No
# 40472                NaN             No
# 40473                NaN             No
#
# [40474 rows x 31 columns]

# %%
df = df1.merge(df2,left_on='Provider',right_on='Provider')
df
# Out:
#            BeneID   ClaimID ClaimStartDt  ClaimEndDt  Provider  \
# 0       BENE11001  CLM46614   2009-04-12  2009-04-18  PRV55912
# 1       BENE17521  CLM34721   2009-01-20  2009-02-01  PRV55912
# 2       BENE21718  CLM72336   2009-10-17  2009-11-04  PRV55912
# 3       BENE22934  CLM73394   2009-10-25  2009-10-29  PRV55912
# 4       BENE24402  CLM32911   2009-01-08  2009-01-12  PRV55912
# ...           ...       ...          ...         ...       ...
# 40469  BENE156181  CLM57017   2009-06-24  2009-07-01  PRV55706
# 40470  BENE156872  CLM67045   2009-09-06  2009-09-13  PRV51572
# 40471  BENE157414  CLM76036   2009-11-15  2009-11-23  PRV55688
# 40472  BENE158281  CLM35143   2009-01-23  2009-01-23  PRV56485
# 40473  BENE159166  CLM38985   2009-02-18  2009-02-25  PRV51812
#
#        InscClaimAmtReimbursed AttendingPhysician OperatingPhysician  \
# 0                       26000          PHY390922                NaN
# 1                       19000          PHY349293          PHY370861
# 2                       17000          PHY334706          PHY334706
# 3                       13000          PHY390614          PHY323689
# 4                        3000          PHY380413          PHY432598
# ...                       ...                ...                ...
# 40469                   12000          PHY319644          PHY319644
# 40470                    5000          PHY407588          PHY311768
# 40471                   14000          PHY409302                NaN
# 40472                   10000          PHY367360          PHY367360
# 40473                    6000          PHY430902          PHY430902
#
#       OtherPhysician AdmissionDt  ... ClmDiagnosisCode_8  ClmDiagnosisCode_9  \
# 0                NaN  2009-04-12  ...              19889                5849
# 1          PHY363291  2009-01-20  ...               2753               E9305
# 2                NaN  2009-10-17  ...              43812                4019
# 3          PHY363291  2009-10-25  ...                NaN                 NaN
# 4                NaN  2009-01-08  ...                NaN                 NaN
# ...              ...         ...  ...                ...                 ...
# 40469      PHY403799  2009-06-24  ...               1985                0414
# 40470      PHY311768  2009-09-06  ...              41401                2639
# 40471            NaN  2009-11-15  ...              V0481                2761
# 40472            NaN  2009-01-23  ...               2866                 NaN
# 40473            NaN  2009-02-18  ...              25000               32723
#
#       ClmDiagnosisCode_10 ClmProcedureCode_1 ClmProcedureCode_2  \
# 0                     NaN                NaN                NaN
# 1                     NaN             7769.0             5849.0
# 2                     NaN             9338.0                NaN
# 3                     NaN             8154.0                NaN
# 4                     NaN             8543.0                NaN
# ...                   ...                ...                ...
# 40469                 NaN             9955.0                NaN
# 40470                 NaN             3326.0                NaN
# 40471                 NaN                NaN                NaN
# 40472                 NaN             9390.0                NaN
# 40473                2724             3324.0                NaN
#
#       ClmProcedureCode_3 ClmProcedureCode_4 ClmProcedureCode_5  \
# 0                    NaN                NaN                NaN
# 1                    NaN                NaN                NaN
# 2                    NaN                NaN                NaN
# 3                    NaN                NaN                NaN
# 4                    NaN                NaN                NaN
# ...                  ...                ...                ...
# 40469                NaN                NaN                NaN
# 40470                NaN                NaN                NaN
# 40471                NaN                NaN                NaN
# 40472                NaN                NaN                NaN
# 40473                NaN                NaN                NaN
#
#       ClmProcedureCode_6 PotentialFraud
# 0                    NaN            Yes
# 1                    NaN            Yes
# 2                    NaN            Yes
# 3                    NaN            Yes
# 4                    NaN            Yes
# ...                  ...            ...
# 40469                NaN             No
# 40470                NaN             No
# 40471                NaN             No
# 40472                NaN             No
# 40473                NaN             No
#
# [40474 rows x 31 columns]

# %%
df[['Provider','PotentialFraud']].describe()
# Out:
#         Provider PotentialFraud
# count      40474          40474
# unique      2092              2
# top     PRV52019            Yes
# freq         516          23402

# %%
df['PotentialFraud'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
df1['Provider'].isin(df2['Provider']).sum()
# Out:
# 40474

# %%
df2.shape
# Out:
# (5410, 2)

# %%
source = 'Provider'
target = 'AttendingPhysician'

G = nx.from_pandas_edgelist(df, source=source, target = target,create_using=nx.Graph())

# %%
nodes_info_dict = {
  'closeness_centrality': nx.closeness_centrality,
  'eigenvector_centrality': nx.eigenvector_centrality_numpy,
  'pagerank': nx.pagerank
}

columns_with_node_infos = ['degree'] + list(nodes_info_dict.keys())

nodes_info = pd.DataFrame.from_dict(dict(nx.degree(G)), orient='index').rename(columns = {0 : 'degree'}).reset_index()

for info, fun in nodes_info_dict.items():
    temp = pd.DataFrame.from_dict(fun(G), orient='index').rename(columns = {0 : info}).reset_index()
    nodes_info = nodes_info.merge(temp, on='index')
    
nodes_info = nodes_info.rename(columns = {'index': 'Physician'})

df_enriched = df[['Provider','PotentialFraud', 'AttendingPhysician']].merge(nodes_info, left_on = 'Provider',  
                           right_on='Physician', how='left').drop('Physician', axis=1)
df_enriched.rename(columns = {k:'Provider_'+k for k in columns_with_node_infos}, inplace = True)

df_enriched = df_enriched.merge(nodes_info, left_on = 'AttendingPhysician', 
                           right_on='Physician', how='left').drop('Physician', axis=1)
df_enriched.rename(columns = {k:'AttendingPhysician_'+k for k in columns_with_node_infos}, inplace = True)

# %%
df_enriched
# Out:
#        Provider PotentialFraud AttendingPhysician  Provider_degree  \
# 0      PRV55912              1          PHY390922               37
# 1      PRV55912              1          PHY349293               37
# 2      PRV55912              1          PHY334706               37
# 3      PRV55912              1          PHY390614               37
# 4      PRV55912              1          PHY380413               37
# ...         ...            ...                ...              ...
# 40469  PRV55706              0          PHY319644                1
# 40470  PRV51572              0          PHY407588                1
# 40471  PRV55688              0          PHY409302                1
# 40472  PRV56485              0          PHY367360                1
# 40473  PRV51812              0          PHY430902                1
#
#        Provider_closeness_centrality  Provider_eigenvector_centrality  \
# 0                           0.002702                     4.453921e-18
# 1                           0.002702                     4.453921e-18
# 2                           0.002702                     4.453921e-18
# 3                           0.002702                     4.453921e-18
# 4                           0.002702                     4.453921e-18
# ...                              ...                              ...
# 40469                       0.000073                     1.126783e-19
# 40470                       0.000073                    -1.540892e-19
# 40471                       0.000073                    -1.439243e-19
# 40472                       0.000073                     3.147734e-20
# 40473                       0.000152                     2.979987e-20
#
#        Provider_pagerank  AttendingPhysician_degree  \
# 0               0.001291                          1
# 1               0.001291                          1
# 2               0.001291                          1
# 3               0.001291                          1
# 4               0.001291                          1
# ...                  ...                        ...
# 40469           0.000073                          1
# 40470           0.000073                          1
# 40471           0.000073                          1
# 40472           0.000073                          1
# 40473           0.000048                          2
#
#        AttendingPhysician_closeness_centrality  \
# 0                                     0.001369
# 1                                     0.001369
# 2                                     0.001369
# 3                                     0.001369
# 4                                     0.001369
# ...                                        ...
# 40469                                 0.000073
# 40470                                 0.000073
# 40471                                 0.000073
# 40472                                 0.000073
# 40473                                 0.000228
#
#        AttendingPhysician_eigenvector_centrality  AttendingPhysician_pagerank
# 0                                   2.106641e-18                     0.000040
# 1                                   1.722557e-18                     0.000040
# 2                                   1.117239e-18                     0.000040
# 3                                   4.058670e-19                     0.000040
# 4                                   1.266283e-18                     0.000040
# ...                                          ...                          ...
# 40469                              -9.398299e-20                     0.000073
# 40470                               5.243089e-20                     0.000073
# 40471                              -3.347993e-19                     0.000073
# 40472                              -8.446735e-24                     0.000073
# 40473                               4.547145e-19                     0.000086
#
# [40474 rows x 11 columns]

# %%
df_enriched['PotentialFraud']=df_enriched['PotentialFraud'].str.replace('Yes','1')
df_enriched['PotentialFraud']=df_enriched['PotentialFraud'].str.replace('No','0')

# %%
fraud=(df_enriched.loc[df_enriched['PotentialFraud'] == '1'])
fraud
# Out:
#        Provider PotentialFraud AttendingPhysician  Provider_degree  \
# 0      PRV55912              1          PHY390922               37
# 1      PRV55912              1          PHY349293               37
# 2      PRV55912              1          PHY334706               37
# 3      PRV55912              1          PHY390614               37
# 4      PRV55912              1          PHY380413               37
# ...         ...            ...                ...              ...
# 40215  PRV55514              1          PHY380221                6
# 40312  PRV56566              1          PHY344703                1
# 40423  PRV55852              1          PHY336944                2
# 40424  PRV55852              1          PHY356585                2
# 40425  PRV55852              1          PHY336944                2
#
#        Provider_closeness_centrality  Provider_eigenvector_centrality  \
# 0                           0.002702                     4.453921e-18
# 1                           0.002702                     4.453921e-18
# 2                           0.002702                     4.453921e-18
# 3                           0.002702                     4.453921e-18
# 4                           0.002702                     4.453921e-18
# ...                              ...                              ...
# 40215                       0.000438                    -1.499273e-19
# 40312                       0.000073                     1.591622e-19
# 40423                       0.000146                     5.745131e-19
# 40424                       0.000146                     5.745131e-19
# 40425                       0.000146                     5.745131e-19
#
#        Provider_pagerank  AttendingPhysician_degree  \
# 0               0.001291                          1
# 1               0.001291                          1
# 2               0.001291                          1
# 3               0.001291                          1
# 4               0.001291                          1
# ...                  ...                        ...
# 40215           0.000242                          1
# 40312           0.000073                          1
# 40423           0.000107                          1
# 40424           0.000107                          1
# 40425           0.000107                          1
#
#        AttendingPhysician_closeness_centrality  \
# 0                                     0.001369
# 1                                     0.001369
# 2                                     0.001369
# 3                                     0.001369
# 4                                     0.001369
# ...                                        ...
# 40215                                 0.000239
# 40312                                 0.000073
# 40423                                 0.000097
# 40424                                 0.000097
# 40425                                 0.000097
#
#        AttendingPhysician_eigenvector_centrality  AttendingPhysician_pagerank
# 0                                   2.106641e-18                     0.000040
# 1                                   1.722557e-18                     0.000040
# 2                                   1.117239e-18                     0.000040
# 3                                   4.058670e-19                     0.000040
# 4                                   1.266283e-18                     0.000040
# ...                                          ...                          ...
# 40215                              -2.347360e-20                     0.000045
# 40312                              -3.876380e-20                     0.000073
# 40423                               2.657205e-19                     0.000056
# 40424                               5.241645e-19                     0.000056
# 40425                               2.657205e-19                     0.000056
#
# [23402 rows x 11 columns]

# %%
new_df=(fraud.loc[fraud['AttendingPhysician_degree'] > 1])
new_df
# Out:
#        Provider PotentialFraud AttendingPhysician  Provider_degree  \
# 178    PRV54986              1                NaN               21
# 183    PRV54986              1                NaN               21
# 532    PRV55215              1          PHY389170               97
# 795    PRV52283              1                NaN                5
# 900    PRV56588              1                NaN               15
# ...         ...            ...                ...              ...
# 39246  PRV57021              1          PHY332787                2
# 39247  PRV57021              1          PHY332787                2
# 39346  PRV54952              1                NaN               11
# 39618  PRV54098              1          PHY343200                6
# 39626  PRV54098              1          PHY343200                6
#
#        Provider_closeness_centrality  Provider_eigenvector_centrality  \
# 178                         0.029538                     1.039249e-02
# 183                         0.029538                     1.039249e-02
# 532                         0.006437                     1.656674e-15
# 795                         0.029297                     9.509263e-03
# 900                         0.029447                     1.004270e-02
# ...                              ...                              ...
# 39246                       0.029312                     9.360369e-03
# 39247                       0.029312                     9.360369e-03
# 39346                       0.029387                     9.822301e-03
# 39618                       0.000457                     1.581780e-18
# 39626                       0.000457                     1.581780e-18
#
#        Provider_pagerank  AttendingPhysician_degree  \
# 178             0.000717                        104
# 183             0.000717                        104
# 532             0.003306                          2
# 795             0.000175                        104
# 900             0.000514                        104
# ...                  ...                        ...
# 39246           0.000067                          2
# 39247           0.000067                          2
# 39346           0.000379                        104
# 39618           0.000225                          2
# 39626           0.000225                          2
#
#        AttendingPhysician_closeness_centrality  \
# 178                                   0.042938
# 183                                   0.042938
# 532                                   0.004235
# 795                                   0.042938
# 900                                   0.042938
# ...                                        ...
# 39246                                 0.022242
# 39247                                 0.022242
# 39346                                 0.042938
# 39618                                 0.000478
# 39626                                 0.000478
#
#        AttendingPhysician_eigenvector_centrality  AttendingPhysician_pagerank
# 178                                 1.291116e-01                     0.003048
# 183                                 1.291116e-01                     0.003048
# 532                                 1.687332e-16                     0.000069
# 795                                 1.291116e-01                     0.003048
# 900                                 1.291116e-01                     0.003048
# ...                                          ...                          ...
# 39246                               6.786480e-04                     0.000071
# 39247                               6.786480e-04                     0.000071
# 39346                               1.291116e-01                     0.003048
# 39618                               5.601944e-19                     0.000074
# 39626                               5.601944e-19                     0.000074
#
# [789 rows x 11 columns]

# %% [markdown]
# #### Implementation for interactive plot

# %%
# !pip install igraph
# !pip install dataiku
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: igraph in /usr/local/lib/python3.7/dist-packages (0.9.11)
# Requirement already satisfied: texttable>=1.6.2 in /usr/local/lib/python3.7/dist-packages (from igraph) (1.6.4)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ERROR: Could not find a version that satisfies the requirement dataiku (from versions: none)
# ERROR: No matching distribution found for dataiku

# %%
# Import libraries


import pandas as pd, numpy as np

import time
import networkx as nx
import random
import igraph as ig

from sklearn.metrics import classification_report, roc_auc_score
from sklearn.preprocessing import StandardScaler
from sklearn.manifold import TSNE
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import StratifiedKFold

from sklearn.manifold import TSNE
from PIL import Image
import io
import os

import igraph as ig
import plotly.io as pio
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots
pio.templates.default = "plotly_white"

import torch 


# %matplotlib inline

# %%
N_NODES = 789 # number of node to include

from matplotlib.pyplot import figure

source = new_df['Provider']
target = new_df['AttendingPhysician']
weight = new_df['PotentialFraud']



df_nodes = pd.DataFrame({
    'node_id': np.arange(len(source)+len(target)),
    'label' : list(source.values)+list(target.values)})

edges = [(i,j) for i,j in zip(source,target)]


G = ig.Graph()

source = new_df['Provider']
target = new_df['AttendingPhysician']
weight = new_df['PotentialFraud']

edges = pd.DataFrame({'source': source,
                      'target': target,
                      'weight': weight})



G = G.DataFrame(edges, directed=False)


G_subgraph = G.subgraph(list(G.vs)[:N_NODES]) if N_NODES > 0 else G


nodes_edges = set([e[0] for e in G_subgraph.get_edgelist()]).union(set([e[1] for e in G_subgraph.get_edgelist()]))
G_subgraph.delete_vertices(list(set(G_subgraph.vs.indices) - nodes_edges))
# Out:
# /usr/local/lib/python3.7/dist-packages/igraph/__init__.py:3478: UserWarning:
#
# In the first two columns of 'edges' NA elements were replaced with string "NA"
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:5182: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
len([e[0] for e in G_subgraph.get_edgelist()])
# Out:
# 789

# %%
layt = G_subgraph.layout('fr')

# %%
len(G_subgraph.get_vertex_dataframe()['name'].unique())
# Out:
# 232

# %%
G_subgraph.get_vertex_dataframe()['name'].unique()[:3]
# Out:
# array(['NA', 'PHY311469', 'PHY313567'], dtype=object)

# %%
list(G_subgraph.get_vertex_dataframe()[G_subgraph.get_vertex_dataframe()['name']=='PHY311002'].index.unique())
# Out:
# []

# %%
def plot_graph(graph, color_nodes, color_edges = 'grey', title = "", node_name="", layt_type = "fr"):
    
    """ Return a projection of the graph."""

    layt = G_subgraph.layout(layt_type) 
    N = len(layt)

    width=800
    height=800

    print(0)

    Xn, Yn = {}, {}
    counter=0
    for label in G_subgraph.get_vertex_dataframe()['name'].unique():
        list_nodes = list(
            G_subgraph.get_vertex_dataframe()[G_subgraph.get_vertex_dataframe()['name']==label].index.unique()
        )
        Xn[label] = [layt[k][0] for k in range(N) if k in list_nodes]
        Yn[label] = [layt[k][1] for k in range(N) if k in list_nodes]
        counter=counter+1
        if(counter%1000==0):
            print(counter)


    print(1)

    Xe, Ye =[], []
    Xt, Yt =[], []
    counter=0
    for k, e in enumerate(G_subgraph.get_edgelist()):
        Xe+=[layt[e[0]][0],layt[e[1]][0], None]
        Ye+=[layt[e[0]][1],layt[e[1]][1], None]
        counter=counter+1
        if(counter%1000==0):
            print(counter)

    print(2)

    labels = G_subgraph.get_vertex_dataframe()['name'].unique()
    labels.sort()

    fig_data = []

    # edges
    fig_data += [
        go.Scatter(
            x=Xe, y=Ye, mode='lines',
            line= dict(color=color_edges, width=1), 
            name='link', showlegend=False, 
        )]

    print(3)

    # nodes
    fig_data += [
        go.Scatter(
            x=Xn[label], y=Yn[label], mode='markers', name='{} {}'.format(node_name, label),
            marker=dict(
                symbol='circle-dot', size=5, color=color_nodes[label],
                line=dict(color=color_nodes[label], width=0.5)),
            text="Label {}".format(label), hoverinfo='text') for label in labels]

    axis=dict(showline=False, 
              zeroline=False,
              showgrid=False,
              showticklabels=False,
              title='')

    print(4)

    layout=go.Layout(title= title,
        font= dict(size=12),
        showlegend=False,
        autosize=False,
        width=width,
        height=height,
        xaxis=go.layout.XAxis(axis),
        yaxis=go.layout.YAxis(axis),
        margin=go.layout.Margin(l=40, r=40, b=85, t=100),
        hovermode='closest'
        )
    print(5)
    
    return go.Figure(data=fig_data, layout=layout)

# %%
# Pick a random color for every class
colors = px.colors.sequential.Plasma
random.shuffle(px.colors.sequential.Plasma)

color_nodes = {
      label : colors[6] for i, 
      label in enumerate(G_subgraph.get_vertex_dataframe()['name'].unique())
      }

# Plot the figure
fig = plot_graph(edges, color_nodes, color_edges = 'grey', 
                 title = "Network - Fraud", node_name = 'article', layt_type = "fr")
# Out:
# 0
# 1
# 2
# 3
# 4
# 5

# %%
# fig

# %%
fig.write_html("file2.html")

# %%
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="a7fd35a7-4099-4994-9401-abcf34ee9d5f" class="plotly-graph-div" style="height:800px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a7fd35a7-4099-4994-9401-abcf34ee9d5f")) {                    Plotly.newPlot(                        "a7fd35a7-4099-4994-9401-abcf34ee9d5f",                        [{"line":{"color":"grey","width":1},"mode":"lines","name":"link","showlegend":false,"x":[2.3056527102753805,1.2633643485741208,null,2.3056527102753805,1.2633643485741208,null,1.7645435783164627,2.5319491804855523,null,2.3056527102753805,5.5097994881284915,null,2.3056527102753805,4.651257336107912,null,-4.021045752819191,-4.694515043399872,null,-4.021045752819191,-4.694515043399872,null,-4.021045752819191,-4.694515043399872,null,-0.7245043262121513,-0.9770579510474149,null,-1.8766446214340833,-0.9770579510474149,null,-0.7245043262121513,-0.9770579510474149,null,-0.7245043262121513,-0.9770579510474149,null,-0.8272018072631564,-0.9770579510474149,null,-0.8272018072631564,-0.9770579510474149,null,-0.8272018072631564,-0.9770579510474149,null,-0.7245043262121513,-0.9770579510474149,null,-0.7245043262121513,-0.9770579510474149,null,-0.7245043262121513,-0.9770579510474149,null,-0.8272018072631564,-0.9770579510474149,null,-0.8272018072631564,-0.9770579510474149,null,-0.8272018072631564,-0.9770579510474149,null,-0.8272018072631564,-0.9770579510474149,null,-0.8272018072631564,-0.9770579510474149,null,-0.7245043262121513,-0.9770579510474149,null,-0.8272018072631564,-0.9770579510474149,null,-0.8272018072631564,-0.9770579510474149,null,2.3056527102753805,2.924662549691929,null,2.3056527102753805,2.924662549691929,null,2.3056527102753805,2.4382795807539313,null,9.524731275816052,9.535538014835431,null,10.472997104243657,9.535538014835431,null,9.889463172122147,9.535538014835431,null,9.524731275816052,9.535538014835431,null,10.472997104243657,9.535538014835431,null,9.889463172122147,9.535538014835431,null,9.524731275816052,9.535538014835431,null,9.524731275816052,9.535538014835431,null,9.889463172122147,9.535538014835431,null,9.889463172122147,9.535538014835431,null,9.889463172122147,9.535538014835431,null,9.889463172122147,9.535538014835431,null,9.889463172122147,9.535538014835431,null,9.889463172122147,9.535538014835431,null,9.524731275816052,9.535538014835431,null,9.524731275816052,9.535538014835431,null,9.889463172122147,9.535538014835431,null,9.889463172122147,9.535538014835431,null,9.889463172122147,9.535538014835431,null,9.889463172122147,9.535538014835431,null,10.472997104243657,9.535538014835431,null,-4.05461248480147,-3.9876529634502584,null,-2.790036881230976,-3.9876529634502584,null,-4.126663351954978,-3.9876529634502584,null,-4.046583954447024,-3.9876529634502584,null,-3.1753181507118144,-3.9876529634502584,null,-4.046583954447024,-3.9876529634502584,null,-4.525609514583832,-3.9876529634502584,null,-4.553103234685868,-3.9876529634502584,null,-4.126663351954978,-3.9876529634502584,null,-5.13887119356098,-3.9876529634502584,null,-4.046583954447024,-3.9876529634502584,null,-5.827864921198715,-3.9876529634502584,null,-5.605602365482332,-3.9876529634502584,null,-4.046583954447024,-3.9876529634502584,null,-3.927210989002499,-3.9876529634502584,null,-3.927210989002499,-3.9876529634502584,null,-3.3665640685862006,-3.9876529634502584,null,-5.200029796414725,-3.9876529634502584,null,-5.4709624209476555,-3.9876529634502584,null,-5.64501469622893,-3.9876529634502584,null,-4.588848169623965,-3.9876529634502584,null,-4.588848169623965,-3.9876529634502584,null,-5.64501469622893,-3.9876529634502584,null,-4.046583954447024,-3.9876529634502584,null,-4.046583954447024,-3.9876529634502584,null,-5.64501469622893,-3.9876529634502584,null,-4.126663351954978,-3.9876529634502584,null,-4.046583954447024,-3.987652963450 ...

# %% [markdown]
# #### Implementation for interactive plot END

# %% [markdown]
# # PR->Provider
# # PH->AttendingPhysician

# %%
# Take a subset of the graph
G_subgraph = G.subgraph(list(G.vs)[:N_NODES]) if N_NODES > 0 else G

# # Delete nodes that are not linked to any other node
# nodes_edges = set([e[0] for e in G_subgraph.get_edgelist()]).union(set([e[1] for e in G_subgraph.get_edgelist()]))
# G_subgraph.delete_vertices(list(set(G_subgraph.vs.indices) - nodes_edges))# https://igraph.org/python/tutorial/latest/tutorial.html#Layout%20algorithms
