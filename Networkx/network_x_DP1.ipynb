# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import networkx as nx

# %%
df1=pd.read_csv('Train_Inpatientdata.csv')
df1.head()
# Out:
#       BeneID   ClaimID ClaimStartDt  ClaimEndDt  Provider  \
# 0  BENE11001  CLM46614   2009-04-12  2009-04-18  PRV55912
# 1  BENE11001  CLM66048   2009-08-31  2009-09-02  PRV55907
# 2  BENE11001  CLM68358   2009-09-17  2009-09-20  PRV56046
# 3  BENE11011  CLM38412   2009-02-14  2009-02-22  PRV52405
# 4  BENE11014  CLM63689   2009-08-13  2009-08-30  PRV56614
#
#    InscClaimAmtReimbursed AttendingPhysician OperatingPhysician  \
# 0                   26000          PHY390922                NaN
# 1                    5000          PHY318495          PHY318495
# 2                    5000          PHY372395                NaN
# 3                    5000          PHY369659          PHY392961
# 4                   10000          PHY379376          PHY398258
#
#   OtherPhysician AdmissionDt  ... ClmDiagnosisCode_7  ClmDiagnosisCode_8  \
# 0            NaN  2009-04-12  ...               2724               19889
# 1            NaN  2009-08-31  ...                NaN                 NaN
# 2      PHY324689  2009-09-17  ...                NaN                 NaN
# 3      PHY349768  2009-02-14  ...              25062               40390
# 4            NaN  2009-08-13  ...               5119               29620
#
#   ClmDiagnosisCode_9 ClmDiagnosisCode_10 ClmProcedureCode_1  \
# 0               5849                 NaN                NaN
# 1                NaN                 NaN             7092.0
# 2                NaN                 NaN                NaN
# 3               4019                 NaN              331.0
# 4              20300                 NaN             3893.0
#
#   ClmProcedureCode_2 ClmProcedureCode_3 ClmProcedureCode_4 ClmProcedureCode_5  \
# 0                NaN                NaN                NaN                NaN
# 1                NaN                NaN                NaN                NaN
# 2                NaN                NaN                NaN                NaN
# 3                NaN                NaN                NaN                NaN
# 4                NaN                NaN                NaN                NaN
#
#   ClmProcedureCode_6
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN
#
# [5 rows x 30 columns]

# %%
df1['Provider']
# Out:
# 0        PRV55912
# 1        PRV55907
# 2        PRV56046
# 3        PRV52405
# 4        PRV56614
#            ...
# 40469    PRV53671
# 40470    PRV54981
# 40471    PRV56588
# 40472    PRV56575
# 40473    PRV54765
# Name: Provider, Length: 40474, dtype: object

# %%
df2=pd.read_csv('Train.csv')
df2.head()
# Out:
#    Provider PotentialFraud
# 0  PRV51001             No
# 1  PRV51003            Yes
# 2  PRV51004             No
# 3  PRV51005            Yes
# 4  PRV51007             No

# %%
df2['Provider'][0]
# Out:
# 'PRV51001'

# %%
df1['Provider'][0]
# Out:
# 'PRV55912'

# %%
df = pd.merge(df1, df2)
df
# Out:
#            BeneID   ClaimID ClaimStartDt  ClaimEndDt  Provider  \
# 0       BENE11001  CLM46614   2009-04-12  2009-04-18  PRV55912
# 1       BENE17521  CLM34721   2009-01-20  2009-02-01  PRV55912
# 2       BENE21718  CLM72336   2009-10-17  2009-11-04  PRV55912
# 3       BENE22934  CLM73394   2009-10-25  2009-10-29  PRV55912
# 4       BENE24402  CLM32911   2009-01-08  2009-01-12  PRV55912
# ...           ...       ...          ...         ...       ...
# 40469  BENE156181  CLM57017   2009-06-24  2009-07-01  PRV55706
# 40470  BENE156872  CLM67045   2009-09-06  2009-09-13  PRV51572
# 40471  BENE157414  CLM76036   2009-11-15  2009-11-23  PRV55688
# 40472  BENE158281  CLM35143   2009-01-23  2009-01-23  PRV56485
# 40473  BENE159166  CLM38985   2009-02-18  2009-02-25  PRV51812
#
#        InscClaimAmtReimbursed AttendingPhysician OperatingPhysician  \
# 0                       26000          PHY390922                NaN
# 1                       19000          PHY349293          PHY370861
# 2                       17000          PHY334706          PHY334706
# 3                       13000          PHY390614          PHY323689
# 4                        3000          PHY380413          PHY432598
# ...                       ...                ...                ...
# 40469                   12000          PHY319644          PHY319644
# 40470                    5000          PHY407588          PHY311768
# 40471                   14000          PHY409302                NaN
# 40472                   10000          PHY367360          PHY367360
# 40473                    6000          PHY430902          PHY430902
#
#       OtherPhysician AdmissionDt  ... ClmDiagnosisCode_8  ClmDiagnosisCode_9  \
# 0                NaN  2009-04-12  ...              19889                5849
# 1          PHY363291  2009-01-20  ...               2753               E9305
# 2                NaN  2009-10-17  ...              43812                4019
# 3          PHY363291  2009-10-25  ...                NaN                 NaN
# 4                NaN  2009-01-08  ...                NaN                 NaN
# ...              ...         ...  ...                ...                 ...
# 40469      PHY403799  2009-06-24  ...               1985                0414
# 40470      PHY311768  2009-09-06  ...              41401                2639
# 40471            NaN  2009-11-15  ...              V0481                2761
# 40472            NaN  2009-01-23  ...               2866                 NaN
# 40473            NaN  2009-02-18  ...              25000               32723
#
#       ClmDiagnosisCode_10 ClmProcedureCode_1 ClmProcedureCode_2  \
# 0                     NaN                NaN                NaN
# 1                     NaN             7769.0             5849.0
# 2                     NaN             9338.0                NaN
# 3                     NaN             8154.0                NaN
# 4                     NaN             8543.0                NaN
# ...                   ...                ...                ...
# 40469                 NaN             9955.0                NaN
# 40470                 NaN             3326.0                NaN
# 40471                 NaN                NaN                NaN
# 40472                 NaN             9390.0                NaN
# 40473                2724             3324.0                NaN
#
#       ClmProcedureCode_3 ClmProcedureCode_4 ClmProcedureCode_5  \
# 0                    NaN                NaN                NaN
# 1                    NaN                NaN                NaN
# 2                    NaN                NaN                NaN
# 3                    NaN                NaN                NaN
# 4                    NaN                NaN                NaN
# ...                  ...                ...                ...
# 40469                NaN                NaN                NaN
# 40470                NaN                NaN                NaN
# 40471                NaN                NaN                NaN
# 40472                NaN                NaN                NaN
# 40473                NaN                NaN                NaN
#
#       ClmProcedureCode_6 PotentialFraud
# 0                    NaN            Yes
# 1                    NaN            Yes
# 2                    NaN            Yes
# 3                    NaN            Yes
# 4                    NaN            Yes
# ...                  ...            ...
# 40469                NaN             No
# 40470                NaN             No
# 40471                NaN             No
# 40472                NaN             No
# 40473                NaN             No
#
# [40474 rows x 31 columns]

# %%
df = df1.merge(df2,left_on='Provider',right_on='Provider')
df
# Out:
#            BeneID   ClaimID ClaimStartDt  ClaimEndDt  Provider  \
# 0       BENE11001  CLM46614   2009-04-12  2009-04-18  PRV55912
# 1       BENE17521  CLM34721   2009-01-20  2009-02-01  PRV55912
# 2       BENE21718  CLM72336   2009-10-17  2009-11-04  PRV55912
# 3       BENE22934  CLM73394   2009-10-25  2009-10-29  PRV55912
# 4       BENE24402  CLM32911   2009-01-08  2009-01-12  PRV55912
# ...           ...       ...          ...         ...       ...
# 40469  BENE156181  CLM57017   2009-06-24  2009-07-01  PRV55706
# 40470  BENE156872  CLM67045   2009-09-06  2009-09-13  PRV51572
# 40471  BENE157414  CLM76036   2009-11-15  2009-11-23  PRV55688
# 40472  BENE158281  CLM35143   2009-01-23  2009-01-23  PRV56485
# 40473  BENE159166  CLM38985   2009-02-18  2009-02-25  PRV51812
#
#        InscClaimAmtReimbursed AttendingPhysician OperatingPhysician  \
# 0                       26000          PHY390922                NaN
# 1                       19000          PHY349293          PHY370861
# 2                       17000          PHY334706          PHY334706
# 3                       13000          PHY390614          PHY323689
# 4                        3000          PHY380413          PHY432598
# ...                       ...                ...                ...
# 40469                   12000          PHY319644          PHY319644
# 40470                    5000          PHY407588          PHY311768
# 40471                   14000          PHY409302                NaN
# 40472                   10000          PHY367360          PHY367360
# 40473                    6000          PHY430902          PHY430902
#
#       OtherPhysician AdmissionDt  ... ClmDiagnosisCode_8  ClmDiagnosisCode_9  \
# 0                NaN  2009-04-12  ...              19889                5849
# 1          PHY363291  2009-01-20  ...               2753               E9305
# 2                NaN  2009-10-17  ...              43812                4019
# 3          PHY363291  2009-10-25  ...                NaN                 NaN
# 4                NaN  2009-01-08  ...                NaN                 NaN
# ...              ...         ...  ...                ...                 ...
# 40469      PHY403799  2009-06-24  ...               1985                0414
# 40470      PHY311768  2009-09-06  ...              41401                2639
# 40471            NaN  2009-11-15  ...              V0481                2761
# 40472            NaN  2009-01-23  ...               2866                 NaN
# 40473            NaN  2009-02-18  ...              25000               32723
#
#       ClmDiagnosisCode_10 ClmProcedureCode_1 ClmProcedureCode_2  \
# 0                     NaN                NaN                NaN
# 1                     NaN             7769.0             5849.0
# 2                     NaN             9338.0                NaN
# 3                     NaN             8154.0                NaN
# 4                     NaN             8543.0                NaN
# ...                   ...                ...                ...
# 40469                 NaN             9955.0                NaN
# 40470                 NaN             3326.0                NaN
# 40471                 NaN                NaN                NaN
# 40472                 NaN             9390.0                NaN
# 40473                2724             3324.0                NaN
#
#       ClmProcedureCode_3 ClmProcedureCode_4 ClmProcedureCode_5  \
# 0                    NaN                NaN                NaN
# 1                    NaN                NaN                NaN
# 2                    NaN                NaN                NaN
# 3                    NaN                NaN                NaN
# 4                    NaN                NaN                NaN
# ...                  ...                ...                ...
# 40469                NaN                NaN                NaN
# 40470                NaN                NaN                NaN
# 40471                NaN                NaN                NaN
# 40472                NaN                NaN                NaN
# 40473                NaN                NaN                NaN
#
#       ClmProcedureCode_6 PotentialFraud
# 0                    NaN            Yes
# 1                    NaN            Yes
# 2                    NaN            Yes
# 3                    NaN            Yes
# 4                    NaN            Yes
# ...                  ...            ...
# 40469                NaN             No
# 40470                NaN             No
# 40471                NaN             No
# 40472                NaN             No
# 40473                NaN             No
#
# [40474 rows x 31 columns]

# %%
df[['Provider','PotentialFraud']].describe()
# Out:
#         Provider PotentialFraud
# count      40474          40474
# unique      2092              2
# top     PRV52019            Yes
# freq         516          23402

# %%
df['PotentialFraud'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
df1['Provider'].isin(df2['Provider']).sum()
# Out:
# 40474

# %%
df2.shape
# Out:
# (5410, 2)

# %%
source = 'Provider'
target = 'AttendingPhysician'

G = nx.from_pandas_edgelist(df, source=source, target = target,create_using=nx.Graph())

# %%
nodes_info_dict = {
  'closeness_centrality': nx.closeness_centrality,
  'eigenvector_centrality': nx.eigenvector_centrality_numpy,
  'pagerank': nx.pagerank
}

columns_with_node_infos = ['degree'] + list(nodes_info_dict.keys())

nodes_info = pd.DataFrame.from_dict(dict(nx.degree(G)), orient='index').rename(columns = {0 : 'degree'}).reset_index()

for info, fun in nodes_info_dict.items():
    temp = pd.DataFrame.from_dict(fun(G), orient='index').rename(columns = {0 : info}).reset_index()
    nodes_info = nodes_info.merge(temp, on='index')
    
nodes_info = nodes_info.rename(columns = {'index': 'Physician'})

df_enriched = df[['Provider','PotentialFraud', 'AttendingPhysician']].merge(nodes_info, left_on = 'Provider',  
                           right_on='Physician', how='left').drop('Physician', axis=1)
df_enriched.rename(columns = {k:'Provider_'+k for k in columns_with_node_infos}, inplace = True)

df_enriched = df_enriched.merge(nodes_info, left_on = 'AttendingPhysician', 
                           right_on='Physician', how='left').drop('Physician', axis=1)
df_enriched.rename(columns = {k:'AttendingPhysician_'+k for k in columns_with_node_infos}, inplace = True)

# %%
df_enriched
# Out:
#        Provider PotentialFraud AttendingPhysician  Provider_degree  \
# 0      PRV55912            Yes          PHY390922               37
# 1      PRV55912            Yes          PHY349293               37
# 2      PRV55912            Yes          PHY334706               37
# 3      PRV55912            Yes          PHY390614               37
# 4      PRV55912            Yes          PHY380413               37
# ...         ...            ...                ...              ...
# 40469  PRV55706             No          PHY319644                1
# 40470  PRV51572             No          PHY407588                1
# 40471  PRV55688             No          PHY409302                1
# 40472  PRV56485             No          PHY367360                1
# 40473  PRV51812             No          PHY430902                1
#
#        Provider_closeness_centrality  Provider_eigenvector_centrality  \
# 0                           0.002702                    -4.051106e-18
# 1                           0.002702                    -4.051106e-18
# 2                           0.002702                    -4.051106e-18
# 3                           0.002702                    -4.051106e-18
# 4                           0.002702                    -4.051106e-18
# ...                              ...                              ...
# 40469                       0.000073                     2.495474e-18
# 40470                       0.000073                    -2.043016e-18
# 40471                       0.000073                    -1.137274e-18
# 40472                       0.000073                     6.233894e-19
# 40473                       0.000152                     1.772470e-18
#
#        Provider_pagerank  AttendingPhysician_degree  \
# 0               0.001291                          1
# 1               0.001291                          1
# 2               0.001291                          1
# 3               0.001291                          1
# 4               0.001291                          1
# ...                  ...                        ...
# 40469           0.000073                          1
# 40470           0.000073                          1
# 40471           0.000073                          1
# 40472           0.000073                          1
# 40473           0.000048                          2
#
#        AttendingPhysician_closeness_centrality  \
# 0                                     0.001369
# 1                                     0.001369
# 2                                     0.001369
# 3                                     0.001369
# 4                                     0.001369
# ...                                        ...
# 40469                                 0.000073
# 40470                                 0.000073
# 40471                                 0.000073
# 40472                                 0.000073
# 40473                                 0.000228
#
#        AttendingPhysician_eigenvector_centrality  AttendingPhysician_pagerank
# 0                                  -7.508173e-19                     0.000040
# 1                                  -1.512126e-18                     0.000040
# 2                                  -2.122392e-18                     0.000040
# 3                                  -1.285085e-18                     0.000040
# 4                                  -1.053399e-18                     0.000040
# ...                                          ...                          ...
# 40469                               6.920907e-19                     0.000073
# 40470                              -2.022396e-18                     0.000073
# 40471                               1.465861e-18                     0.000073
# 40472                              -1.706477e-18                     0.000073
# 40473                               1.666252e-18                     0.000086
#
# [40474 rows x 11 columns]

# %%
df_enriched['PotentialFraud']=df_enriched['PotentialFraud'].str.replace('Yes','1')
df_enriched['PotentialFraud']=df_enriched['PotentialFraud'].str.replace('No','0')

# %%
fraud=(df_enriched.loc[df_enriched['PotentialFraud'] == '1'])
fraud
# Out:
#        Provider PotentialFraud AttendingPhysician  Provider_degree  \
# 0      PRV55912              1          PHY390922               37
# 1      PRV55912              1          PHY349293               37
# 2      PRV55912              1          PHY334706               37
# 3      PRV55912              1          PHY390614               37
# 4      PRV55912              1          PHY380413               37
# ...         ...            ...                ...              ...
# 40215  PRV55514              1          PHY380221                6
# 40312  PRV56566              1          PHY344703                1
# 40423  PRV55852              1          PHY336944                2
# 40424  PRV55852              1          PHY356585                2
# 40425  PRV55852              1          PHY336944                2
#
#        Provider_closeness_centrality  Provider_eigenvector_centrality  \
# 0                           0.002702                    -4.051106e-18
# 1                           0.002702                    -4.051106e-18
# 2                           0.002702                    -4.051106e-18
# 3                           0.002702                    -4.051106e-18
# 4                           0.002702                    -4.051106e-18
# ...                              ...                              ...
# 40215                       0.000438                    -5.296059e-18
# 40312                       0.000073                    -1.021538e-18
# 40423                       0.000146                     2.208820e-18
# 40424                       0.000146                     2.208820e-18
# 40425                       0.000146                     2.208820e-18
#
#        Provider_pagerank  AttendingPhysician_degree  \
# 0               0.001291                          1
# 1               0.001291                          1
# 2               0.001291                          1
# 3               0.001291                          1
# 4               0.001291                          1
# ...                  ...                        ...
# 40215           0.000242                          1
# 40312           0.000073                          1
# 40423           0.000107                          1
# 40424           0.000107                          1
# 40425           0.000107                          1
#
#        AttendingPhysician_closeness_centrality  \
# 0                                     0.001369
# 1                                     0.001369
# 2                                     0.001369
# 3                                     0.001369
# 4                                     0.001369
# ...                                        ...
# 40215                                 0.000239
# 40312                                 0.000073
# 40423                                 0.000097
# 40424                                 0.000097
# 40425                                 0.000097
#
#        AttendingPhysician_eigenvector_centrality  AttendingPhysician_pagerank
# 0                                  -7.508173e-19                     0.000040
# 1                                  -1.512126e-18                     0.000040
# 2                                  -2.122392e-18                     0.000040
# 3                                  -1.285085e-18                     0.000040
# 4                                  -1.053399e-18                     0.000040
# ...                                          ...                          ...
# 40215                              -9.397165e-19                     0.000045
# 40312                               2.189726e-18                     0.000073
# 40423                               2.624092e-18                     0.000056
# 40424                               1.618632e-18                     0.000056
# 40425                               2.624092e-18                     0.000056
#
# [23402 rows x 11 columns]

# %%
new_df=(fraud.loc[fraud['AttendingPhysician_degree'] > 1])
new_df
# Out:
#        Provider PotentialFraud AttendingPhysician  Provider_degree  \
# 178    PRV54986              1                NaN               21
# 183    PRV54986              1                NaN               21
# 532    PRV55215              1          PHY389170               97
# 795    PRV52283              1                NaN                5
# 900    PRV56588              1                NaN               15
# ...         ...            ...                ...              ...
# 39246  PRV57021              1          PHY332787                2
# 39247  PRV57021              1          PHY332787                2
# 39346  PRV54952              1                NaN               11
# 39618  PRV54098              1          PHY343200                6
# 39626  PRV54098              1          PHY343200                6
#
#        Provider_closeness_centrality  Provider_eigenvector_centrality  \
# 178                         0.029538                     1.039249e-02
# 183                         0.029538                     1.039249e-02
# 532                         0.006437                    -1.773642e-16
# 795                         0.029297                     9.509263e-03
# 900                         0.029447                     1.004270e-02
# ...                              ...                              ...
# 39246                       0.029312                     9.360369e-03
# 39247                       0.029312                     9.360369e-03
# 39346                       0.029387                     9.822301e-03
# 39618                       0.000457                     4.977305e-18
# 39626                       0.000457                     4.977305e-18
#
#        Provider_pagerank  AttendingPhysician_degree  \
# 178             0.000717                        104
# 183             0.000717                        104
# 532             0.003306                          2
# 795             0.000175                        104
# 900             0.000514                        104
# ...                  ...                        ...
# 39246           0.000067                          2
# 39247           0.000067                          2
# 39346           0.000379                        104
# 39618           0.000225                          2
# 39626           0.000225                          2
#
#        AttendingPhysician_closeness_centrality  \
# 178                                   0.042938
# 183                                   0.042938
# 532                                   0.004235
# 795                                   0.042938
# 900                                   0.042938
# ...                                        ...
# 39246                                 0.022242
# 39247                                 0.022242
# 39346                                 0.042938
# 39618                                 0.000478
# 39626                                 0.000478
#
#        AttendingPhysician_eigenvector_centrality  AttendingPhysician_pagerank
# 178                                 1.291116e-01                     0.003048
# 183                                 1.291116e-01                     0.003048
# 532                                -8.322924e-18                     0.000069
# 795                                 1.291116e-01                     0.003048
# 900                                 1.291116e-01                     0.003048
# ...                                          ...                          ...
# 39246                               6.786480e-04                     0.000071
# 39247                               6.786480e-04                     0.000071
# 39346                               1.291116e-01                     0.003048
# 39618                               2.681223e-18                     0.000074
# 39626                               2.681223e-18                     0.000074
#
# [789 rows x 11 columns]

# %% [markdown]
# #### Implementation for interactive plot

# %%
# !pip install igraph
# !pip install dataiku
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: igraph in /usr/local/lib/python3.7/dist-packages (0.9.11)
# Requirement already satisfied: texttable>=1.6.2 in /usr/local/lib/python3.7/dist-packages (from igraph) (1.6.4)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ERROR: Could not find a version that satisfies the requirement dataiku (from versions: none)
# ERROR: No matching distribution found for dataiku

# %%
# Import libraries


import pandas as pd, numpy as np

import time
import networkx as nx
import random
import igraph as ig

from sklearn.metrics import classification_report, roc_auc_score
from sklearn.preprocessing import StandardScaler
from sklearn.manifold import TSNE
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import StratifiedKFold

from sklearn.manifold import TSNE
from PIL import Image
import io
import os

import igraph as ig
import plotly.io as pio
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots
pio.templates.default = "plotly_white"

import torch 


# %matplotlib inline

# %%
N_NODES = 789 # number of node to include

from matplotlib.pyplot import figure

source = new_df['Provider']
target = new_df['AttendingPhysician']
weight = new_df['PotentialFraud']



df_nodes = pd.DataFrame({
    'node_id': np.arange(len(source)+len(target)),
    'label' : list(source.values)+list(target.values)})

edges = [(i,j) for i,j in zip(source,target)]


G = ig.Graph()

source = new_df['Provider']
target = new_df['AttendingPhysician']
weight = new_df['PotentialFraud']

edges = pd.DataFrame({'source': source,
                      'target': target,
                      'weight': weight})



G = G.DataFrame(edges, directed=False)


G_subgraph = G.subgraph(list(G.vs)[:N_NODES]) if N_NODES > 0 else G


nodes_edges = set([e[0] for e in G_subgraph.get_edgelist()]).union(set([e[1] for e in G_subgraph.get_edgelist()]))
G_subgraph.delete_vertices(list(set(G_subgraph.vs.indices) - nodes_edges))
# Out:
# /usr/local/lib/python3.7/dist-packages/igraph/__init__.py:3478: UserWarning:
#
# In the first two columns of 'edges' NA elements were replaced with string "NA"
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:5182: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
len([e[0] for e in G_subgraph.get_edgelist()])
# Out:
# 789

# %%
layt = G_subgraph.layout('fr')

# %%
len(G_subgraph.get_vertex_dataframe()['name'].unique())
# Out:
# 232

# %%
G_subgraph.get_vertex_dataframe()['name'].unique()[:3]
# Out:
# array(['NA', 'PHY311469', 'PHY313567'], dtype=object)

# %%
list(G_subgraph.get_vertex_dataframe()[G_subgraph.get_vertex_dataframe()['name']=='PHY311002'].index.unique())
# Out:
# []

# %%
def plot_graph(graph, color_nodes, color_edges = 'grey', title = "", node_name="", layt_type = "fr"):
    
    """ Return a projection of the graph."""

    layt = G_subgraph.layout(layt_type) 
    N = len(layt)

    width=800
    height=800

    print(0)

    Xn, Yn = {}, {}
    counter=0
    for label in G_subgraph.get_vertex_dataframe()['name'].unique():
        list_nodes = list(
            G_subgraph.get_vertex_dataframe()[G_subgraph.get_vertex_dataframe()['name']==label].index.unique()
        )
        Xn[label] = [layt[k][0] for k in range(N) if k in list_nodes]
        Yn[label] = [layt[k][1] for k in range(N) if k in list_nodes]
        counter=counter+1
        if(counter%1000==0):
            print(counter)


    print(1)

    Xe, Ye =[], []
    Xt, Yt =[], []
    counter=0
    for k, e in enumerate(G_subgraph.get_edgelist()):
        Xe+=[layt[e[0]][0],layt[e[1]][0], None]
        Ye+=[layt[e[0]][1],layt[e[1]][1], None]
        counter=counter+1
        if(counter%1000==0):
            print(counter)

    print(2)

    labels = G_subgraph.get_vertex_dataframe()['name'].unique()
    labels.sort()

    fig_data = []

    # edges
    fig_data += [
        go.Scatter(
            x=Xe, y=Ye, mode='lines',
            line= dict(color=color_edges, width=1), 
            name='link', showlegend=False, 
        )]

    print(3)
    
    # nodes
    fig_data += [
        go.Scatter(
            x=Xn[label], y=Yn[label], mode='markers', name='{} {}'.format(node_name, label),
            marker=dict(
                symbol='circle-dot', size=5, color=color_nodes[label],
                line=dict(color=color_nodes[label], width=0.5)),
            text="Label {}".format(label), hoverinfo='text') for label in labels]

    axis=dict(showline=False, 
              zeroline=False,
              showgrid=False,
              showticklabels=False,
              title='')

    print(4)

    layout=go.Layout(title= title,
        font= dict(size=12),
        showlegend=False,
        autosize=False,
        width=width,
        height=height,
        xaxis=go.layout.XAxis(axis),
        yaxis=go.layout.YAxis(axis),
        margin=go.layout.Margin(l=40, r=40, b=85, t=100),
        hovermode='closest'
        )
    print(5)
    
    return go.Figure(data=fig_data, layout=layout)

# %%
# Pick a random color for every class
colors = px.colors.sequential.Plasma
random.shuffle(px.colors.sequential.Plasma)

color_nodes = {
      label : colors[6] for i, 
      label in enumerate(G_subgraph.get_vertex_dataframe()['name'].unique())
      }

# Plot the figure
fig = plot_graph(edges,color_nodes, color_edges = 'grey', 
                 title = "Network - Fraud", node_name = 'article', layt_type = "fr")
# Out:
# 0
# 1
# 2
# 3
# 4
# 5

# %%
# fig

# %%
fig.write_html("fraud.html")

# %% [markdown]
# # Fraudulent Data

# %%
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="b5e2e2e2-fcbc-4b95-b8b7-e6ff3041e973" class="plotly-graph-div" style="height:800px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b5e2e2e2-fcbc-4b95-b8b7-e6ff3041e973")) {                    Plotly.newPlot(                        "b5e2e2e2-fcbc-4b95-b8b7-e6ff3041e973",                        [{"line":{"color":"grey","width":1},"mode":"lines","name":"link","showlegend":false,"x":[0.7468479566674203,0.24903754029862418,null,0.7468479566674203,0.24903754029862418,null,-4.140990678180349,-3.427778234950835,null,0.7468479566674203,3.0948786213522212,null,0.7468479566674203,3.3939728838826664,null,-10.6135073296653,-10.241915705140489,null,-10.6135073296653,-10.241915705140489,null,-10.6135073296653,-10.241915705140489,null,0.7193158271332248,0.19488572107549773,null,0.10842104896120498,0.19488572107549773,null,0.7193158271332248,0.19488572107549773,null,0.7193158271332248,0.19488572107549773,null,-0.3114644003376338,0.19488572107549773,null,-0.3114644003376338,0.19488572107549773,null,-0.3114644003376338,0.19488572107549773,null,0.7193158271332248,0.19488572107549773,null,0.7193158271332248,0.19488572107549773,null,0.7193158271332248,0.19488572107549773,null,-0.3114644003376338,0.19488572107549773,null,-0.3114644003376338,0.19488572107549773,null,-0.3114644003376338,0.19488572107549773,null,-0.3114644003376338,0.19488572107549773,null,-0.3114644003376338,0.19488572107549773,null,0.7193158271332248,0.19488572107549773,null,-0.3114644003376338,0.19488572107549773,null,-0.3114644003376338,0.19488572107549773,null,0.7468479566674203,1.3188435991988887,null,0.7468479566674203,1.3188435991988887,null,0.7468479566674203,-0.683879190805148,null,9.271715856978648,9.71031956878689,null,9.208623688161124,9.71031956878689,null,9.70288880641735,9.71031956878689,null,9.271715856978648,9.71031956878689,null,9.208623688161124,9.71031956878689,null,9.70288880641735,9.71031956878689,null,9.271715856978648,9.71031956878689,null,9.271715856978648,9.71031956878689,null,9.70288880641735,9.71031956878689,null,9.70288880641735,9.71031956878689,null,9.70288880641735,9.71031956878689,null,9.70288880641735,9.71031956878689,null,9.70288880641735,9.71031956878689,null,9.70288880641735,9.71031956878689,null,9.271715856978648,9.71031956878689,null,9.271715856978648,9.71031956878689,null,9.70288880641735,9.71031956878689,null,9.70288880641735,9.71031956878689,null,9.70288880641735,9.71031956878689,null,9.70288880641735,9.71031956878689,null,9.208623688161124,9.71031956878689,null,-2.738424764319891,-1.8737561403156193,null,-1.7732929606372467,-1.8737561403156193,null,-1.4015092964414877,-1.8737561403156193,null,-1.486542135275783,-1.8737561403156193,null,-2.2436313257774296,-1.8737561403156193,null,-1.486542135275783,-1.8737561403156193,null,-3.2692400227119194,-1.8737561403156193,null,0.22576576269856358,-1.8737561403156193,null,-1.4015092964414877,-1.8737561403156193,null,-2.886344285678451,-1.8737561403156193,null,-1.486542135275783,-1.8737561403156193,null,-0.5191131595732915,-1.8737561403156193,null,-4.181486072290759,-1.8737561403156193,null,-1.486542135275783,-1.8737561403156193,null,-1.940767496720466,-1.8737561403156193,null,-1.940767496720466,-1.8737561403156193,null,-1.0352986680491898,-1.8737561403156193,null,-2.574765739148838,-1.8737561403156193,null,-3.076730151337614,-1.8737561403156193,null,-3.6511135891054316,-1.8737561403156193,null,-2.4811241608979024,-1.8737561403156193,null,-2.4811241608979024,-1.8737561403156193,null,-3.6511135891054316,-1.8737561403156193,null,-1.486542135275783,-1.8737561403156193,null,-1.486542135275783,-1.8737561403156193,null,-3.6511135891054316,-1.8737561403156193,null,-1.4015092964414877,-1.8737561403156193,null,-1.486542135275783,-1.8737561403156193,null,-2.243631325 ...

# %% [markdown]
# #### Implementation for interactive plot END

# %% [markdown]
# # PR->Provider
# # PH->AttendingPhysician

# %%
non_fraud=(df_enriched.loc[df_enriched['PotentialFraud'] == '0'])
non_fraud
# Out:
#        Provider PotentialFraud AttendingPhysician  Provider_degree  \
# 60     PRV55907              0          PHY318495               35
# 61     PRV55907              0          PHY369014               35
# 62     PRV55907              0          PHY328529               35
# 63     PRV55907              0          PHY391371               35
# 64     PRV55907              0          PHY376827               35
# ...         ...            ...                ...              ...
# 40469  PRV55706              0          PHY319644                1
# 40470  PRV51572              0          PHY407588                1
# 40471  PRV55688              0          PHY409302                1
# 40472  PRV56485              0          PHY367360                1
# 40473  PRV51812              0          PHY430902                1
#
#        Provider_closeness_centrality  Provider_eigenvector_centrality  \
# 60                          0.002555                    -9.835395e-18
# 61                          0.002555                    -9.835395e-18
# 62                          0.002555                    -9.835395e-18
# 63                          0.002555                    -9.835395e-18
# 64                          0.002555                    -9.835395e-18
# ...                              ...                              ...
# 40469                       0.000073                     2.495474e-18
# 40470                       0.000073                    -2.043016e-18
# 40471                       0.000073                    -1.137274e-18
# 40472                       0.000073                     6.233894e-19
# 40473                       0.000152                     1.772470e-18
#
#        Provider_pagerank  AttendingPhysician_degree  \
# 60              0.001224                          1
# 61              0.001224                          1
# 62              0.001224                          1
# 63              0.001224                          1
# 64              0.001224                          1
# ...                  ...                        ...
# 40469           0.000073                          1
# 40470           0.000073                          1
# 40471           0.000073                          1
# 40472           0.000073                          1
# 40473           0.000048                          2
#
#        AttendingPhysician_closeness_centrality  \
# 60                                    0.001296
# 61                                    0.001296
# 62                                    0.001296
# 63                                    0.001296
# 64                                    0.001296
# ...                                        ...
# 40469                                 0.000073
# 40470                                 0.000073
# 40471                                 0.000073
# 40472                                 0.000073
# 40473                                 0.000228
#
#        AttendingPhysician_eigenvector_centrality  AttendingPhysician_pagerank
# 60                                 -2.023880e-18                     0.000040
# 61                                 -3.835582e-18                     0.000040
# 62                                 -3.519376e-18                     0.000040
# 63                                 -3.926345e-18                     0.000040
# 64                                 -3.830632e-18                     0.000040
# ...                                          ...                          ...
# 40469                               6.920907e-19                     0.000073
# 40470                              -2.022396e-18                     0.000073
# 40471                               1.465861e-18                     0.000073
# 40472                              -1.706477e-18                     0.000073
# 40473                               1.666252e-18                     0.000086
#
# [17072 rows x 11 columns]

# %%
final_df=(non_fraud.loc[non_fraud['AttendingPhysician_degree'] > 1])
final_df
# Out:
#        Provider PotentialFraud AttendingPhysician  Provider_degree  \
# 134    PRV52405              0          PHY369659                7
# 135    PRV52405              0          PHY392961                7
# 136    PRV52405              0          PHY369659                7
# 137    PRV52405              0          PHY423095                7
# 139    PRV52405              0          PHY423095                7
# ...         ...            ...                ...              ...
# 40391  PRV54668              0          PHY413688                1
# 40414  PRV56576              0          PHY348088                1
# 40447  PRV54902              0          PHY364095                1
# 40451  PRV56540              0          PHY329323                1
# 40473  PRV51812              0          PHY430902                1
#
#        Provider_closeness_centrality  Provider_eigenvector_centrality  \
# 134                         0.000530                    -2.088848e-18
# 135                         0.000530                    -2.088848e-18
# 136                         0.000530                    -2.088848e-18
# 137                         0.000530                    -2.088848e-18
# 139                         0.000530                    -2.088848e-18
# ...                              ...                              ...
# 40391                       0.001128                     2.153516e-18
# 40414                       0.017999                     5.221720e-05
# 40447                       0.000152                     1.232492e-18
# 40451                       0.000110                     1.588796e-19
# 40473                       0.000152                     1.772470e-18
#
#        Provider_pagerank  AttendingPhysician_degree  \
# 134             0.000185                          2
# 135             0.000185                          2
# 136             0.000185                          2
# 137             0.000185                          2
# 139             0.000185                          2
# ...                  ...                        ...
# 40391           0.000044                          2
# 40414           0.000043                          2
# 40447           0.000048                          2
# 40451           0.000051                          2
# 40473           0.000048                          2
#
#        AttendingPhysician_closeness_centrality  \
# 134                                   0.000550
# 135                                   0.000550
# 136                                   0.000550
# 137                                   0.000550
# 139                                   0.000550
# ...                                        ...
# 40391                                 0.001486
# 40414                                 0.022399
# 40447                                 0.000228
# 40451                                 0.000164
# 40473                                 0.000228
#
#        AttendingPhysician_eigenvector_centrality  AttendingPhysician_pagerank
# 134                                 1.260675e-18                     0.000056
# 135                                 6.695750e-19                     0.000056
# 136                                 1.260675e-18                     0.000056
# 137                                 1.927540e-18                     0.000056
# 139                                 1.927540e-18                     0.000056
# ...                                          ...                          ...
# 40391                              -1.460088e-18                     0.000077
# 40414                               7.240403e-04                     0.000075
# 40447                               3.863767e-18                     0.000086
# 40451                               1.071748e-18                     0.000095
# 40473                               1.666252e-18                     0.000086
#
# [624 rows x 11 columns]

# %%
N_NODES = 624 # number of node to include

from matplotlib.pyplot import figure

source = final_df['Provider']
target = final_df['AttendingPhysician']
weight = final_df['PotentialFraud']



df_nodes = pd.DataFrame({
    'node_id': np.arange(len(source)+len(target)),
    'label' : list(source.values)+list(target.values)})

edges = [(i,j) for i,j in zip(source,target)]


G = ig.Graph()

source = final_df['Provider']
target = final_df['AttendingPhysician']
weight = final_df['PotentialFraud']

edges = pd.DataFrame({'source': source,
                      'target': target,
                      'weight': weight})



G = G.DataFrame(edges, directed=False)


G_subgraph = G.subgraph(list(G.vs)[:N_NODES]) if N_NODES > 0 else G


nodes_edges = set([e[0] for e in G_subgraph.get_edgelist()]).union(set([e[1] for e in G_subgraph.get_edgelist()]))
G_subgraph.delete_vertices(list(set(G_subgraph.vs.indices) - nodes_edges))
# Out:
# /usr/local/lib/python3.7/dist-packages/igraph/__init__.py:3478: UserWarning:
#
# In the first two columns of 'edges' NA elements were replaced with string "NA"
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:5182: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
len(G_subgraph.get_vertex_dataframe()['name'].unique())
G_subgraph.get_vertex_dataframe()['name'].unique()[:3]
# Out:
# array(['NA', 'PHY311147', 'PHY311469'], dtype=object)

# %%
def plot_graph(graph, color_nodes, color_edges = 'grey', title = "", node_name="", layt_type = "fr"):
    
    """ Return a projection of the graph."""

    layt = G_subgraph.layout(layt_type) 
    N = len(layt)

    width=800
    height=800

    print(0)

    Xn, Yn = {}, {}
    counter=0
    for label in G_subgraph.get_vertex_dataframe()['name'].unique():
        list_nodes = list(
            G_subgraph.get_vertex_dataframe()[G_subgraph.get_vertex_dataframe()['name']==label].index.unique()
        )
        Xn[label] = [layt[k][0] for k in range(N) if k in list_nodes]
        Yn[label] = [layt[k][1] for k in range(N) if k in list_nodes]
        counter=counter+1
        if(counter%1000==0):
            print(counter)


    print(1)

    Xe, Ye =[], []
    Xt, Yt =[], []
    counter=0
    for k, e in enumerate(G_subgraph.get_edgelist()):
        Xe+=[layt[e[0]][0],layt[e[1]][0], None]
        Ye+=[layt[e[0]][1],layt[e[1]][1], None]
        counter=counter+1
        if(counter%1000==0):
            print(counter)

    print(2)

    labels = G_subgraph.get_vertex_dataframe()['name'].unique()
    labels.sort()

    fig_data = []

    # edges
    fig_data += [
        go.Scatter(
            x=Xe, y=Ye, mode='lines',
            line= dict(color=color_edges, width=1), 
            name='link', showlegend=False, 
        )]

    print(3)
    
    # nodes
    fig_data += [
        go.Scatter(
            x=Xn[label], y=Yn[label], mode='markers', name='{} {}'.format(node_name, label),
            marker=dict(
                symbol='circle-dot', size=5, color=color_nodes[label],
                line=dict(color=color_nodes[label], width=0.5)),
            text="Label {}".format(label), hoverinfo='text') for label in labels]

    axis=dict(showline=False, 
              zeroline=False,
              showgrid=False,
              showticklabels=False,
              title='')

    print(4)

    layout=go.Layout(title= title,
        font= dict(size=12),
        showlegend=False,
        autosize=False,
        width=width,
        height=height,
        xaxis=go.layout.XAxis(axis),
        yaxis=go.layout.YAxis(axis),
        margin=go.layout.Margin(l=40, r=40, b=85, t=100),
        hovermode='closest'
        )
    print(5)
    
    return go.Figure(data=fig_data, layout=layout)

# %%
colors = px.colors.sequential.Plasma
random.shuffle(px.colors.sequential.Plasma)

color_nodes = {
      label : colors[6] for i, 
      label in enumerate(G_subgraph.get_vertex_dataframe()['name'].unique())
      }

# Plot the figure
fig = plot_graph(edges,color_nodes, color_edges = 'grey', 
                 title = "Network - Fraud", node_name = 'article', layt_type = "fr")
# Out:
# 0
# 1
# 2
# 3
# 4
# 5

# %% [markdown]
# # NON_FRAUDULENT

# %%
fig.write_html("non-fraud.html")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="35f8a6af-d41d-4b77-a28e-b256ec9c2a8b" class="plotly-graph-div" style="height:800px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("35f8a6af-d41d-4b77-a28e-b256ec9c2a8b")) {                    Plotly.newPlot(                        "35f8a6af-d41d-4b77-a28e-b256ec9c2a8b",                        [{"line":{"color":"grey","width":1},"mode":"lines","name":"link","showlegend":false,"x":[-3.647493149679463,-4.050297478508431,null,-3.070215657185547,-4.050297478508431,null,-3.647493149679463,-4.050297478508431,null,-4.573117903851737,-4.050297478508431,null,-4.573117903851737,-4.050297478508431,null,-4.898507663382771,-4.050297478508431,null,-4.267097035626741,-4.050297478508431,null,-3.647493149679463,-4.050297478508431,null,-4.573117903851737,-4.050297478508431,null,-3.647493149679463,-4.050297478508431,null,-2.916646051266998,-4.050297478508431,null,-4.573117903851737,-4.050297478508431,null,-4.573117903851737,-4.050297478508431,null,-2.916646051266998,-4.050297478508431,null,-4.267097035626741,-4.050297478508431,null,4.610426408471923,4.692135385461862,null,4.9298899329864625,4.692135385461862,null,8.037773628951243,10.636843053604526,null,8.037773628951243,7.689597931288625,null,13.271286246353597,13.79656281775674,null,1.7408336568359817,1.9947287917139969,null,1.7408336568359817,1.9947287917139969,null,1.7408336568359817,1.9947287917139969,null,2.218513142860924,1.9947287917139969,null,2.218513142860924,1.9947287917139969,null,1.7408336568359817,1.9947287917139969,null,2.218513142860924,1.9947287917139969,null,1.7408336568359817,1.9947287917139969,null,1.7408336568359817,1.9947287917139969,null,-15.677966140454547,-15.615605032574427,null,-15.677966140454547,-15.615605032574427,null,-15.677966140454547,-15.615605032574427,null,13.044039299738982,12.339862471085134,null,1.8472279098322848,1.903230089470336,null,1.8472279098322848,1.903230089470336,null,1.8472279098322848,1.903230089470336,null,1.8472279098322848,1.903230089470336,null,1.8472279098322848,1.903230089470336,null,1.9266948404851423,1.903230089470336,null,1.8472279098322848,1.903230089470336,null,1.9266948404851423,1.903230089470336,null,0.8239944700208884,1.903230089470336,null,-11.76684558946342,-12.382879994974422,null,-11.76684558946342,-12.382879994974422,null,10.464357790467297,11.31489614626381,null,-0.8789907691034728,-0.9575184123032209,null,-0.8789907691034728,-0.9575184123032209,null,-0.8789907691034728,-0.9575184123032209,null,-0.8789907691034728,-0.9575184123032209,null,-0.8789907691034728,-0.9575184123032209,null,-0.8789907691034728,-0.9575184123032209,null,-0.8789907691034728,-0.9575184123032209,null,-0.8789907691034728,-0.9575184123032209,null,-0.8789907691034728,-0.9575184123032209,null,-0.8789907691034728,-0.9575184123032209,null,-0.8789907691034728,-0.9575184123032209,null,-0.8789907691034728,-0.9575184123032209,null,-0.8789907691034728,-0.9575184123032209,null,-0.8789907691034728,-0.9575184123032209,null,-0.8789907691034728,-0.9575184123032209,null,-0.8789907691034728,-0.9575184123032209,null,-0.8789907691034728,-0.9575184123032209,null,-0.8789907691034728,-0.9575184123032209,null,-0.8789907691034728,-0.9575184123032209,null,-0.8789907691034728,-0.9575184123032209,null,-0.8789907691034728,-0.9575184123032209,null,-0.8789907691034728,-0.9575184123032209,null,-0.8789907691034728,-0.9575184123032209,null,-0.8789907691034728,-0.9575184123032209,null,-0.8789907691034728,-0.9575184123032209,null,-0.8789907691034728,-0.9575184123032209,null,-0.8789907691034728,-0.9575184123032209,null,-0.8789907691034728,-0.9575184123032209,null,-0.8789907691034728,-0.9575184123032209,null,-0.8789907691034728,-0.9575184123032209,null,-0.8789907691034728,-0.9575184123032209,null,-0.8789907691034728,-0.9575184123032209,null,- ...

# %%
# Take a subset of the graph
G_subgraph = G.subgraph(list(G.vs)[:N_NODES]) if N_NODES > 0 else G

# # Delete nodes that are not linked to any other node
# nodes_edges = set([e[0] for e in G_subgraph.get_edgelist()]).union(set([e[1] for e in G_subgraph.get_edgelist()]))
# G_subgraph.delete_vertices(list(set(G_subgraph.vs.indices) - nodes_edges))# https://igraph.org/python/tutorial/latest/tutorial.html#Layout%20algorithms
